# %%
import torch

if torch.cuda.is_available():
    device = torch.device("cuda")
    print("GPU is available and ready to use:", torch.cuda.get_device_name(device))
else:
    device = torch.device("cpu")
    print("GPU not available, using CPU instead.")
# Out:
# GPU is available and ready to use: Tesla T4

# %%
# !pip install transformers gtts moviepy pdfminer.six
# !pip install tensorflow
# !pip install keras
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 69.4 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline
from gtts import gTTS
import moviepy.editor as mp
from pdfminer.high_level import extract_text
import os

# %%
# !sudo apt-get install espeak # Install the eSpeak TTS engine
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   espeak-data libespeak1 libportaudio2 libsonic0
# The following NEW packages will be installed:
#   espeak espeak-data libespeak1 libportaudio2 libsonic0
# 0 upgraded, 5 newly installed, 0 to remove and 45 not upgraded.
# Need to get 1,382 kB of archives.
# After this operation, 3,178 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libportaudio2 amd64 19.6.0-1.1 [65.3 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsonic0 amd64 0.2.0-11build1 [10.3 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 espeak-data amd64 1.48.15+dfsg-3 [1,085 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libespeak1 amd64 1.48.15+dfsg-3 [156 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 espeak amd64 1.48.15+dfsg-3 [64.2 kB]
# ...

# %%
# !pip install transformers gtts moviepy pdfminer.six pyttsx3 # Install pyttsx3
from transformers import pipeline
from gtts import gTTS
import moviepy.editor as mp
from pdfminer.high_level import extract_text
import os
import pyttsx3 # Import the missing module
import IPython.display as ipd

# %%
# !pip install opencv-python-headless moviepy
# !wget https://randomuser.me/api/portraits/men/1.jpg
# Out:
# ...
# --2024-08-04 15:34:01--  https://randomuser.me/api/portraits/men/1.jpg
# Resolving randomuser.me (randomuser.me)... 104.21.90.128, 172.67.156.167, 2606:4700:3034::ac43:9ca7, ...
# Connecting to randomuser.me (randomuser.me)|104.21.90.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3598 (3.5K) [image/jpeg]
# Saving to: ‘1.jpg’
#
# 1.jpg               100%[===================>]   3.51K  --.-KB/s    in 0s
#
# 2024-08-04 15:34:01 (49.9 MB/s) - ‘1.jpg’ saved [3598/3598]

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from gtts import gTTS
import os

# Function to generate text using GPT-2
def generate_text(prompt, max_length=100):
    model_name = 'gpt2'
    model = GPT2LMHeadModel.from_pretrained(model_name)
    tokenizer = GPT2Tokenizer.from_pretrained(model_name)

    inputs = tokenizer.encode(prompt, return_tensors='pt')
    outputs = model.generate(inputs, max_length=max_length, num_return_sequences=1)

    text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return text

# Function to convert text to speech and save as output.wav
def text_to_speech(text, filename="output.wav"):
    tts = gTTS(text)
    tts.save(filename)

# %%
# Get user input for the prompt
prompt = input("Enter your prompt: ")

# Generate text based on the prompt
generated_text = generate_text(prompt)
print("Generated Text:", generated_text)

# Convert the generated text to speech and save as output.wav
text_to_speech(generated_text)
print("Audio saved as output.wav")
# Out:
# Enter your prompt: Explain Global Warming
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# ...

# %%
# !pip install librosa moviepy
# !git clone https://github.com/Rudrabha/Wav2Lip.git
# Out:
# ...
# Cloning into 'Wav2Lip'...
# remote: Enumerating objects: 381, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 381 (delta 0), reused 1 (delta 0), pack-reused 378
# Receiving objects: 100% (381/381), 534.01 KiB | 2.06 MiB/s, done.
# Resolving deltas: 100% (210/210), done.

# %%
from google.colab import files

uploaded = files.upload()

# After uploading, move the file to the desired directory
import shutil

shutil.move('wav2lip_gan.pth', '/content/Wav2Lip/checkpoints/wav2lip_gan.pth')
# Out:
#      <input type="file" id="files-bf0ae169-d5e1-497d-b1de-8c93cd6a5880" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf0ae169-d5e1-497d-b1de-8c93cd6a5880">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import sys

# Set the working directory to the location of audio.py
os.chdir('/content/Wav2Lip')  # Adjust this path as needed

# Add the current directory to the system path
sys.path.append(os.getcwd())

# Now, import the audio module
import audio

# %%
from os import listdir, path
import numpy as np
import scipy, cv2, os, sys, argparse
#Check to see if 'audio.py' exists in the current directory
#If it doesn't exist, you may need to create it or obtain it from the source of the Wav2Lip project
import audio
import json, subprocess, random, string
from tqdm import tqdm

# %%
import os
video_path = '/content/1.jpg'
audio_path = '/content/output.wav'
checkpoint_path = '/content/Wav2Lip/checkpoints/wav2lip_gan.pth'
outfile_path = '/content/result_video.mp4'

print(f"Video file exists: {os.path.isfile(video_path)}")
print(f"Audio file exists: {os.path.isfile(audio_path)}")
print(f"Checkpoint file exists: {os.path.isfile(checkpoint_path)}")
# Out:
# Video file exists: True
# Audio file exists: True
# Checkpoint file exists: True

# %%
# !file /content/Wav2Lip/checkpoints/wav2lip_gan.pth
# Out:
# /content/Wav2Lip/checkpoints/wav2lip_gan.pth: data

# %%
#To check the size of model
# !ls -l /content/Wav2Lip/checkpoints/wav2lip_gan.pth
# Out:
# -rw-r--r-- 1 root root 435801865 Aug  4 19:00 /content/Wav2Lip/checkpoints/wav2lip_gan.pth

# %%
# !python /content/Wav2Lip/inference.py --checkpoint_path /content/Wav2Lip/checkpoints/wav2lip_gan.pth --face /content/1.jpg --audio /content/output.wav --outfile /content/result_video.mp4
# Out:
# Using cuda for inference.
# Number of frames available for inference: 1
# (80, 2842)
# Length of mel chunks: 885
#   0% 0/7 [00:00<?, ?it/s]Downloading: "https://www.adrianbulat.com/downloads/python-fan/s3fd-619a316812.pth" to /root/.cache/torch/hub/checkpoints/s3fd-619a316812.pth
#
#   0% 0.00/85.7M [00:00<?, ?B/s]
#   0% 128k/85.7M [00:00<03:25, 437kB/s]
#   0% 256k/85.7M [00:00<02:24, 618kB/s]
#   0% 384k/85.7M [00:00<02:05, 713kB/s]
#   1% 640k/85.7M [00:00<01:23, 1.07MB/s]
#   1% 1.12M/85.7M [00:00<00:47, 1.88MB/s]
#   2% 2.12M/85.7M [00:01<00:24, 3.52MB/s]
#   5% 4.25M/85.7M [00:01<00:12, 7.09MB/s]
#   8% 7.12M/85.7M [00:01<00:07, 11.1MB/s]
#  12% 10.6M/85.7M [00:01<00:05, 15.1MB/s]
#  16% 13.9M/85.7M [00:01<00:04, 17.4MB/s]
#  20% 17.2M/85.7M [00:01<00:03, 19.3MB/s]
#  24% 20.4M/85.7M [00:01<00:03, 20.1MB/s]
#  28% 23.9M/85.7M [00:02<00:03, 21.4MB/s]
#  32% 27.0M/85.7M [00:02<00:02, 21.2MB/s]
#  35% 30.0M/85.7M [00:02<00:02, 21.1MB/s]
# ...
